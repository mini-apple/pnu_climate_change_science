# %% [markdown]
# # 1-1.  Visualization with Python

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('C:/Users/UICHEOL/Desktop/기후변화과학/HW1/practice_data.csv')

data
# Out:
#       country3 country2      country region subregion  \
# 0          ABW       AW        Aruba      -         -
# 1          ABW       AW        Aruba     SA         -
# 2          AFG       AF  Afghanistan    BAL         -
# 3          AFG       AF  Afghanistan    BAL         -
# 4          AFG       AF  Afghanistan    BAL         -
# ...        ...      ...          ...    ...       ...
# 41798      ZZZ       ZZ      Unknown    NaN       NaN
# 41799      ZZZ       ZZ      Unknown    NaN       NaN
# 41800      ZZZ       ZZ      Unknown    NaN       NaN
# 41801      ZZZ       ZZ      Unknown    NaN       NaN
# 41802      ZZZ       ZZ      Unknown    NaN       NaN
#
#                                     place_name    wmo        lat        lon  \
# 0                                  Old Norwood  78850  16.791111 -62.193333
# 1                            Upper Hell's Gate  78871  17.646111 -63.220833
# 2           Kyzylabad|Mazar-I-Sharif|Qizil?b?d  40911  36.700000  67.200000
# ...

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib import style

style.use("seaborn-talk")
m = Basemap(projection="mill")
m.drawcoastlines()
m.drawcountries()

for i in data.index :
    x, y = m(data['lon'][i], data['lat'][i])
    m.plot(x, y,'bo', ms=0.5)     

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

style.use("seaborn-talk")
m = Basemap(projection="robin", resolution="i", area_thresh=1000.0, lat_0=0, lon_0=0)
m.drawcoastlines()
m.drawcountries()
#m.fillcontinents(color="gray")
m.drawmapboundary()
m.drawmeridians(np.arange(0,360,30))
m.drawparallels(np.arange(-90,90,30))

for i in data.index :
    x, y = m(data['lon'][i], data['lat'][i])
    m.plot(x, y,'bo', ms=0.5)  

plt.show()
